# %% [markdown]
# # Assignment-1

# %% [markdown]
# ## TASK 1

# %% [markdown]
# Q.No.1

# %% [markdown]
# ![First_Program.png](attachment:First_Program.png)

# %% [markdown]
# Q.No.2

# %%
number = list(range(2000,3201))
Div = []
for i in n:
    if (i%7==0):
        if(i%5 == 0):
            continue
        Div.append(i)

print(*seven, sep=",",end=".")
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199.

# %% [markdown]
# Q.No.3

# %%
first_name = input("your first name : ")
last_name = input("your last name : ")
print(last_name +" "+ first_name)
# Out:
# your first name : pavan
# your last name : raut
# raut pavan

# %% [markdown]
# Q.No.4

# %%
d = 12
r = d/2
pi = 3.14
V = 4/3*pi*r**3
print('The Volume of Sphere: ',V)
# Out:
# The Volume of Sphere:  904.3199999999999

# %% [markdown]
# ## TASK 2

# %% [markdown]
# Q.No.1

# %%
num = input("From comma-seperated numbers of sequence:\n List:\n")

num = num.split(",")

print(num)
# Out:
# From comma-seperated numbers of sequence:
#  List:
# 55,8,8,85,86,8
# ['55', '8', '8', '85', '86', '8']

# %% [markdown]
# Q.No.2

# %%
for i in range(0, 5):
    for j in range(0, i):
        print("*",end="")
    print()
for i in range(0, 5):
    for j in range(5, i, -1):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# Q.No.3

# %%
sample = input("Input a word to reverse : ")
for a in range(len(sample) -1, -1, -1):
    print(sample[a], end="")
# Out:
# Input a word to reverse : pavan
# navap

# %% [markdown]
# Q.No.4

# %%
print("""WE, THE PEOPLE OF INDIA,\n\t having solemnly resolved to constitute India into a SOVEREIGN,!\n\t\t SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC\n\t\t  and to secure to all its citizens""")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	 having solemnly resolved to constitute India into a SOVEREIGN,!
# 		 SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		  and to secure to all its citizens
